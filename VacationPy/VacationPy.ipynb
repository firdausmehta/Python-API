# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import gmaps
import os

# Import API key
from api_keys import g_key

# %%
csv_file = os.path.join('..', 'WeatherPy', 'Output', 'city_weather.csv')

city_df = pd.read_csv(csv_file)
city_df
# Out:
#      City ID          City Country      Lat       Lng  Temperature  Humidity  \
# 0     986717  Kruisfontein      ZA -34.0033   24.7314        53.35        80
# 1     553878          Kama      RU  56.3051   54.0936        62.71        90
# 2    3652764  Puerto Ayora      EC  -0.7393  -90.3518        73.54        89
# 3    3440777         Rocha      UY -34.4833  -54.3333        49.95        65
# 4    1497210    Novoagansk      RU  61.9449   76.6625        64.81        38
# ..       ...           ...     ...      ...       ...          ...       ...
# 575  2396518   Port-Gentil      GA  -0.7193    8.7815        77.67        82
# 576  3984997   San Quintín      MX  30.4833 -115.9500        66.34        79
# 577  2690170        Nässjö      SE  57.6531   14.6968        50.92        73
# 578  2189343          Kaeo      NZ -35.1000  173.7833        62.33        75
# 579  3994469       Ojinaga      MX  29.5667 -104.4167        88.75        29
#
#      Clouds  Wind Speed
# 0         0        6.51
# 1        99       12.01
# 2        37        4.00
# 3       100        8.52
# 4         2        6.11
# ..      ...         ...
# 575      94       11.52
# 576       2        2.30
# 577      90        4.45
# 578       9        7.72
# 579       1       19.57
#
# [580 rows x 9 columns]

# %%
gmaps.configure(api_key=g_key)

# %%
locations = city_df[["Lat", "Lng"]]
humidity = city_df["Humidity"]

fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False)
heat_layer.max_intensity = 100
heat_layer.point_radius = 5


fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
